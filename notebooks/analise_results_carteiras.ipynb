# %%
import json
with open("results_dict_2.json", "r") as f:
    results_dict = json.load(f)
    
with open("results_marcowitz.json", "r") as f:
    results_dict_marcowitz = json.load(f)

# %%
pesos_carteiras = {}
for key in results_dict.keys():
    pesos_carteiras[key.split(" a ")[1]] = results_dict[key]["tickers_weights"]
    
pesos_carteiras_marcowitz = {}
for key in results_dict_marcowitz.keys():
    pesos_carteiras_marcowitz[key.split(" a ")[1]] = results_dict_marcowitz[key]

# %%
chaves = list(pesos_carteiras.keys())
chave_no_indice = chaves[0]

chaves_marcowitz = list(pesos_carteiras_marcowitz.keys())
chave_no_indice_marcowitz = chaves_marcowitz[0]

# %%
import yfinance as yf
import logging
import pandas as pd
import datetime
logging.basicConfig(level=logging.INFO)
logger = logging.getLogger(__name__)

chaves = list(pesos_carteiras.keys())

precos_carteira = {}

for key, value in enumerate(chaves):
    acoes = list(pesos_carteiras[value].keys())
    acoes_sa = [acao if acao.endswith(".SA") else f"{acao}.SA"  for acao in acoes]
    start = value
    if value == chaves[-1]:
        end = datetime.datetime.now().strftime("%Y-%m-%d")
    else:    
        end = chaves[key+1]
    logger.info(f"Baixando dados de {start} a {end}, para as acoes {acoes_sa}")
    precos_carteira[value] = yf.download(acoes_sa, start=str(start), end= str(end))["Close"]
    

chaves_marcowitz = list(pesos_carteiras_marcowitz.keys())

precos_carteira_marcowitz = {}

for key, value in enumerate(chaves_marcowitz):
    acoes = list(pesos_carteiras_marcowitz[value].keys())
    acoes_sa = [acao if acao.endswith(".SA") else f"{acao}.SA"  for acao in acoes]
    start = value
    if value == chaves_marcowitz[-1]:
        end = datetime.datetime.now().strftime("%Y-%m-%d")
    else:    
        end = chaves_marcowitz[key+1]
    logger.info(f"Baixando dados de {start} a {end}, para as acoes {acoes_sa}")
    precos_carteira_marcowitz[value] = yf.download(acoes_sa, start=str(start), end= str(end))["Close"]

# %%
def daily_returns(prices):
    return prices.pct_change()[1:]

def cumulative_returns(df):
    return (df.apply(daily_returns)+1).cumprod()

def retorno_carteira_monetario(df, pesos, valor_investido):
    pesos_frac = [p/100 for p in pesos]
    valor_investido_carteira = [valor_investido * peso for peso in pesos_frac]
    retorno_carteira = (cumulative_returns(df) * valor_investido_carteira).sum(axis=1)
    return retorno_carteira

def retorno_percentual_acao_individual(pesos_carteiras, precos_carteira):
    """pesos_frac = [p/100 for p in pesos_carteiras[chaves[keys]].values()]
    valor_investido_carteira = [1000 * peso for peso in pesos_frac]
    retorno_carteira = (cumulative_returns(precos_carteira[chaves[keys]]) * valor_investido_carteira)"""
    
    
    pesos_frac = [p/100 for p in pesos_carteiras.values()]
    valor_investido_carteira = [1000 * peso for peso in pesos_frac]
    
    # Usar diretamente precos_df (já é o DataFrame correto)
    retorno_carteira = cumulative_returns(precos_carteira) * valor_investido_carteira
    
    retorno_percentual = retorno_carteira.apply(
        lambda x: (x.iloc[-1] - x.iloc[0]) / x.iloc[0] * 100
    )
    return retorno_percentual

# %%
def verificando_valores_nulos(keys, pesos_carteiras, precos_carteira):
    dict_keys = pesos_carteiras[chaves[keys]].copy()
    null = precos_carteira[chaves[keys]].isna().any()
    list_name_null = precos_carteira[chaves[keys]].loc[:,null].columns.to_list()
    
    dict_keys = {
        (key if key.endswith(".SA") else f"{key}.SA"): value 
        for key, value in pesos_carteiras[chaves[keys]].items()
    }
    valor_do_tic_null = 0
    for tic in list_name_null:
        valor_do_tic_null += dict_keys[tic]
        dict_keys.pop(tic)  # Remover cada ticker individualmente
    
    quantidade_sobrou = len(dict_keys)
    
    if quantidade_sobrou == 0:
        return {}  # Evitar divisão por zero
    
    valor_para_cada_tic = valor_do_tic_null / quantidade_sobrou
    
    dict_com_novos_valores = {}
    for key, value in dict_keys.items():
        dict_com_novos_valores[key] = value + valor_para_cada_tic
    
    return dict_com_novos_valores

# %%
from IPython.display import display, Markdown
carteira = pd.DataFrame()
carteira_marcowitz = pd.DataFrame()
for key, value in enumerate(chaves):
    
    print("*" * 40)
    
    display(Markdown(f"**O retorno da carteira para o período: {value}**"))
    
    ## Pesos selecionados pelo modelo
    pesos_sem_erro = verificando_valores_nulos(key, pesos_carteiras, precos_carteira)
    
    precos_sem_nan = precos_carteira[chaves[key]].dropna(axis=1)
    
    carteira_percentual_acoes = retorno_percentual_acao_individual(pesos_sem_erro, precos_sem_nan)
    
    # carteira de markowits
    try:
        pesos_sem_erro_markowitz = verificando_valores_nulos(key, pesos_carteiras_marcowitz, precos_carteira_marcowitz)
        pesos_sem_erro_markowitz = {key_: value*100 for key_, value in pesos_sem_erro_markowitz.items()}
    
        precos_sem_nan_markwitz = precos_carteira_marcowitz[chaves[key]].dropna(axis=1)
    
        carteira_percentual_acoes_marcowitz = retorno_percentual_acao_individual(pesos_sem_erro_markowitz, precos_sem_nan_markwitz)
    except Exception as e:  
        logger.info(f"Erro ao obter:{e}")
    
    data = pd.DataFrame(pesos_sem_erro, index=["Pesos"]).T
    data_markwitz = pd.DataFrame(pesos_sem_erro_markowitz, index=["Pesos"]).T
    
    if not carteira_percentual_acoes.empty:
        data['retornos em %'] = pd.DataFrame(carteira_percentual_acoes)
        data_markwitz['retornos markwitz em %'] = pd.DataFrame(carteira_percentual_acoes_marcowitz)
    else:
        print("Nenhum dado foi obtido!")
        
    display(data.T.style.set_caption("Pesos").background_gradient(cmap="Blues"))
    
    display(data_markwitz.T.style.set_caption("Pesos").background_gradient(cmap="Blues"))

    if key == 0:
        valor_carteira = retorno_carteira_monetario(precos_sem_nan, pesos_sem_erro.values(), 1000)
        
        valor_carteira_markwitz = retorno_carteira_monetario(precos_sem_nan_markwitz, pesos_sem_erro_markowitz.values(), 1000)

        
    else:   
        valor_carteira = retorno_carteira_monetario(precos_sem_nan, pesos_sem_erro.values(), valor_atual_carteira)
        
        valor_carteira_markwitz = retorno_carteira_monetario(precos_sem_nan_markwitz, pesos_sem_erro_markowitz.values(), valor_atual_carteira_markwitz)
    
    carteira = pd.concat([carteira, valor_carteira])
    carteira_marcowitz = pd.concat([carteira_marcowitz, valor_carteira_markwitz])
    
    try:
        valor_atual_carteira = int(valor_carteira.iloc[-1])
        valor_atual_carteira_markwitz = int(valor_carteira_markwitz.iloc[-1])
    
    except:
        pass
# Out:
# ****************************************
# **O retorno da carteira para o período: 2016-12-31**
# <style type="text/css">
# #T_8ac5e_row0_col0, #T_8ac5e_row0_col3, #T_8ac5e_row0_col6, #T_8ac5e_row1_col1, #T_8ac5e_row1_col2, #T_8ac5e_row1_col4, #T_8ac5e_row1_col5 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_8ac5e_row0_col1, #T_8ac5e_row0_col2, #T_8ac5e_row0_col4, #T_8ac5e_row0_col5, #T_8ac5e_row1_col0, #T_8ac5e_row1_col3, #T_8ac5e_row1_col6 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_8ac5e">
#   <caption>Pesos</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8ac5e_level0_col0" class="col_heading level0 col0" >CSUD3.SA</th>
#       <th id="T_8ac5e_level0_col1" class="col_heading level0 col1" >CGAS3.SA</th>
#       <th id="T_8ac5e_level0_col2" class="col_heading level0 col2" >MDIA3.SA</th>
#       <th id="T_8ac5e_level0_col3" class="col_heading level0 col3" >FLRY3.SA</th>
#       <th id="T_8ac5e_level0_col4" class="col_heading level0 col4" >VIVT3.SA</th>
#       <th id="T_8ac5e_level0_col5" class="col_heading level0 col5" >ABEV3.SA</th>
#       <th id="T_8ac5e_level0_col6" class="col_heading level0 col6" >ITUB4.SA</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8ac5e_level0_row0" class="row_heading level0 row0" >Pesos</th>
#       <td id="T_8ac5e_row0_col0" class="data row0 col0" >16.665139</td>
#       <td id="T_8ac5e_row0_col1" class="data row0 col1" >16.665139</td>
#       <td id="T_8ac5e_row0_col2" class="data row0 col2" >16.665139</td>
#       <td id="T_8ac5e_row0_col3" class="data row0 col3" >16.665139</td>
#       <td id="T_8ac5e_row0_col4" class="data row0 col4" >12.503438</td>
#       <td id="T_8ac5e_row0_col5" class="data row0 col5" >13.337611</td>
#       <td id="T_8ac5e_row0_col6" class="data row0 col6" >7.498396</td>
#     </tr>
#     <tr>
#       <th id="T_8ac5e_level0_row1" class="row_heading level0 row1" >retornos em %</th>
#       <td id="T_8ac5e_row1_col0" class="data row1 col0" >98.591556</td>
#       <td id="T_8ac5e_row1_col1" class="data row1 col1" >6.209619</td>
#       <td id="T_8ac5e_row1_col2" class="data row1 col2" >7.899010</td>
#       <td id="T_8ac5e_row1_col3" class="data row1 col3" >23.443060</td>
#       <td id="T_8ac5e_row1_col4" class="data row1 col4" >7.174964</td>
#       <td id="T_8ac5e_row1_col5" class="data row1 col5" >10.240713</td>
#       <td id="T_8ac5e_row1_col6" class="data row1 col6" >12.482768</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_f345f_row0_col0, #T_f345f_row0_col1, #T_f345f_row0_col4, #T_f345f_row0_col6, #T_f345f_row1_col2, #T_f345f_row1_col3, #T_f345f_row1_col5 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_f345f_row0_col2, #T_f345f_row0_col3, #T_f345f_row0_col5, #T_f345f_row1_col0, #T_f345f_row1_col1, #T_f345f_row1_col4, #T_f345f_row1_col6 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# </style>
# <table id="T_f345f">
#   <caption>Pesos</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f345f_level0_col0" class="col_heading level0 col0" >ABEV3.SA</th>
#       <th id="T_f345f_level0_col1" class="col_heading level0 col1" >CGAS3.SA</th>
#       <th id="T_f345f_level0_col2" class="col_heading level0 col2" >CSUD3.SA</th>
#       <th id="T_f345f_level0_col3" class="col_heading level0 col3" >FLRY3.SA</th>
#       <th id="T_f345f_level0_col4" class="col_heading level0 col4" >ITUB4.SA</th>
#       <th id="T_f345f_level0_col5" class="col_heading level0 col5" >MDIA3.SA</th>
#       <th id="T_f345f_level0_col6" class="col_heading level0 col6" >VIVT3.SA</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f345f_level0_row0" class="row_heading level0 row0" >Pesos</th>
#       <td id="T_f345f_row0_col0" class="data row0 col0" >19.834362</td>
#       <td id="T_f345f_row0_col1" class="data row0 col1" >14.594217</td>
#       <td id="T_f345f_row0_col2" class="data row0 col2" >6.384908</td>
#       <td id="T_f345f_row0_col3" class="data row0 col3" >10.411643</td>
#       <td id="T_f345f_row0_col4" class="data row0 col4" >14.569841</td>
#       <td id="T_f345f_row0_col5" class="data row0 col5" >4.967669</td>
#       <td id="T_f345f_row0_col6" class="data row0 col6" >29.237360</td>
#     </tr>
#     <tr>
#       <th id="T_f345f_level0_row1" class="row_heading level0 row1" >retornos markwitz em %</th>
#       <td id="T_f345f_row1_col0" class="data row1 col0" >10.240706</td>
#       <td id="T_f345f_row1_col1" class="data row1 col1" >6.209608</td>
#       <td id="T_f345f_row1_col2" class="data row1 col2" >98.591615</td>
#       <td id="T_f345f_row1_col3" class="data row1 col3" >23.443021</td>
#       <td id="T_f345f_row1_col4" class="data row1 col4" >12.482897</td>
#       <td id="T_f345f_row1_col5" class="data row1 col5" >7.899059</td>
#       <td id="T_f345f_row1_col6" class="data row1 col6" >7.174952</td>
#     </tr>
#   </tbody>
# </table>
# ****************************************
# C:\Users\jefer\AppData\Local\Temp\ipykernel_4584\2885132824.py:52: FutureWarning: The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#   carteira = pd.concat([carteira, valor_carteira])
# C:\Users\jefer\AppData\Local\Temp\ipykernel_4584\2885132824.py:53: FutureWarning: The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#   carteira_marcowitz = pd.concat([carteira_marcowitz, valor_carteira_markwitz])
# **O retorno da carteira para o período: 2017-03-31**
# C:\Users\jefer\AppData\Local\Temp\ipykernel_4584\1529076990.py:26: RuntimeWarning: invalid value encountered in scalar divide
#   lambda x: (x.iloc[-1] - x.iloc[0]) / x.iloc[0] * 100
# <style type="text/css">
# #T_c99c4_row0_col0, #T_c99c4_row0_col1, #T_c99c4_row0_col2, #T_c99c4_row0_col3, #T_c99c4_row0_col4, #T_c99c4_row0_col5, #T_c99c4_row0_col6 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_c99c4_row1_col0, #T_c99c4_row1_col1, #T_c99c4_row1_col2, #T_c99c4_row1_col3, #T_c99c4_row1_col4, #T_c99c4_row1_col5, #T_c99c4_row1_col6 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# </style>
# <table id="T_c99c4">
#   <caption>Pesos</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c99c4_level0_col0" class="col_heading level0 col0" >ABEV3.SA</th>
#       <th id="T_c99c4_level0_col1" class="col_heading level0 col1" >LREN3.SA</th>
#       <th id="T_c99c4_level0_col2" class="col_heading level0 col2" >BBDC4.SA</th>
#       <th id="T_c99c4_level0_col3" class="col_heading level0 col3" >ITUB4.SA</th>
#       <th id="T_c99c4_level0_col4" class="col_heading level0 col4" >EGIE3.SA</th>
#       <th id="T_c99c4_level0_col5" class="col_heading level0 col5" >CSUD3.SA</th>
#       <th id="T_c99c4_level0_col6" class="col_heading level0 col6" >PSSA3.SA</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c99c4_level0_row0" class="row_heading level0 row0" >Pesos</th>
#       <td id="T_c99c4_row0_col0" class="data row0 col0" >15.000000</td>
#       <td id="T_c99c4_row0_col1" class="data row0 col1" >20.000000</td>
#       <td id="T_c99c4_row0_col2" class="data row0 col2" >15.000000</td>
#       <td id="T_c99c4_row0_col3" class="data row0 col3" >15.000000</td>
#       <td id="T_c99c4_row0_col4" class="data row0 col4" >15.000000</td>
#       <td id="T_c99c4_row0_col5" class="data row0 col5" >15.000000</td>
#       <td id="T_c99c4_row0_col6" class="data row0 col6" >5.000000</td>
#     </tr>
#     <tr>
#       <th id="T_c99c4_level0_row1" class="row_heading level0 row1" >retornos em %</th>
#       <td id="T_c99c4_row1_col0" class="data row1 col0" >2.286159</td>
#       <td id="T_c99c4_row1_col1" class="data row1 col1" >6.857338</td>
#       <td id="T_c99c4_row1_col2" class="data row1 col2" >-6.354043</td>
#       <td id="T_c99c4_row1_col3" class="data row1 col3" >-5.141785</td>
#       <td id="T_c99c4_row1_col4" class="data row1 col4" >-2.381546</td>
#       <td id="T_c99c4_row1_col5" class="data row1 col5" >-8.099782</td>
#       <td id="T_c99c4_row1_col6" class="data row1 col6" >4.572203</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_1ba06_row0_col0, #T_1ba06_row0_col1, #T_1ba06_row0_col2, #T_1ba06_row0_col3, #T_1ba06_row0_col4, #T_1ba06_row0_col6 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_1ba06_row0_col5, #T_1ba06_row1_col0, #T_1ba06_row1_col1, #T_1ba06_row1_col2, #T_1ba06_row1_col3, #T_1ba06_row1_col4, #T_1ba06_row1_col5, #T_1ba06_row1_col6 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# </style>
# <table id="T_1ba06">
#   <caption>Pesos</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1ba06_level0_col0" class="col_heading level0 col0" >ABEV3.SA</th>
#       <th id="T_1ba06_level0_col1" class="col_heading level0 col1" >BBDC4.SA</th>
#       <th id="T_1ba06_level0_col2" class="col_heading level0 col2" >CSUD3.SA</th>
#       <th id="T_1ba06_level0_col3" class="col_heading level0 col3" >EGIE3.SA</th>
#       <th id="T_1ba06_level0_col4" class="col_heading level0 col4" >ITUB4.SA</th>
#       <th id="T_1ba06_level0_col5" class="col_heading level0 col5" >LREN3.SA</th>
#       <th id="T_1ba06_level0_col6" class="col_heading level0 col6" >PSSA3.SA</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1ba06_level0_row0" class="row_heading level0 row0" >Pesos</th>
#       <td id="T_1ba06_row0_col0" class="data row0 col0" >25.421836</td>
#       <td id="T_1ba06_row0_col1" class="data row0 col1" >0.000000</td>
#       <td id="T_1ba06_row0_col2" class="data row0 col2" >4.928108</td>
#       <td id="T_1ba06_row0_col3" class="data row0 col3" >41.944427</td>
#       <td id="T_1ba06_row0_col4" class="data row0 col4" >4.195528</td>
#       <td id="T_1ba06_row0_col5" class="data row0 col5" >0.000000</td>
#       <td id="T_1ba06_row0_col6" class="data row0 col6" >23.510101</td>
#     </tr>
#     <tr>
#       <th id="T_1ba06_level0_row1" class="row_heading level0 row1" >retornos markwitz em %</th>
#       <td id="T_1ba06_row1_col0" class="data row1 col0" >2.286144</td>
#       <td id="T_1ba06_row1_col1" class="data row1 col1" >-6.353982</td>
#       <td id="T_1ba06_row1_col2" class="data row1 col2" >-8.099790</td>
#       <td id="T_1ba06_row1_col3" class="data row1 col3" >-2.381546</td>
#       <td id="T_1ba06_row1_col4" class="data row1 col4" >-5.141812</td>
#       <td id="T_1ba06_row1_col5" class="data row1 col5" >nan</td>
#       <td id="T_1ba06_row1_col6" class="data row1 col6" >4.572203</td>
#     </tr>
#   </tbody>
# </table>
# ****************************************
# **O retorno da carteira para o período: 2017-06-30**
# <style type="text/css">
# #T_27450_row0_col0, #T_27450_row0_col2, #T_27450_row0_col5, #T_27450_row1_col1, #T_27450_row1_col3, #T_27450_row1_col4, #T_27450_row1_col6, #T_27450_row1_col7, #T_27450_row1_col8 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_27450_row0_col1, #T_27450_row0_col3, #T_27450_row0_col4, #T_27450_row0_col6, #T_27450_row0_col7, #T_27450_row0_col8, #T_27450_row1_col0, #T_27450_row1_col2, #T_27450_row1_col5 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# </style>
# <table id="T_27450">
#   <caption>Pesos</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_27450_level0_col0" class="col_heading level0 col0" >ABEV3.SA</th>
#       <th id="T_27450_level0_col1" class="col_heading level0 col1" >CSUD3.SA</th>
#       <th id="T_27450_level0_col2" class="col_heading level0 col2" >FLRY3.SA</th>
#       <th id="T_27450_level0_col3" class="col_heading level0 col3" >GGBR4.SA</th>
#       <th id="T_27450_level0_col4" class="col_heading level0 col4" >PSSA3.SA</th>
#       <th id="T_27450_level0_col5" class="col_heading level0 col5" >VALE3.SA</th>
#       <th id="T_27450_level0_col6" class="col_heading level0 col6" >WEGE3.SA</th>
#       <th id="T_27450_level0_col7" class="col_heading level0 col7" >VIVT3.SA</th>
#       <th id="T_27450_level0_col8" class="col_heading level0 col8" >RENT3.SA</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_27450_level0_row0" class="row_heading level0 row0" >Pesos</th>
#       <td id="T_27450_row0_col0" class="data row0 col0" >18.686869</td>
#       <td id="T_27450_row0_col1" class="data row0 col1" >5.050505</td>
#       <td id="T_27450_row0_col2" class="data row0 col2" >18.686869</td>
#       <td id="T_27450_row0_col3" class="data row0 col3" >5.050505</td>
#       <td id="T_27450_row0_col4" class="data row0 col4" >5.050505</td>
#       <td id="T_27450_row0_col5" class="data row0 col5" >18.686869</td>
#       <td id="T_27450_row0_col6" class="data row0 col6" >18.686869</td>
#       <td id="T_27450_row0_col7" class="data row0 col7" >5.050505</td>
#       <td id="T_27450_row0_col8" class="data row0 col8" >5.050505</td>
#     </tr>
#     <tr>
#       <th id="T_27450_level0_row1" class="row_heading level0 row1" >retornos em %</th>
#       <td id="T_27450_row1_col0" class="data row1 col0" >15.098486</td>
#       <td id="T_27450_row1_col1" class="data row1 col1" >21.666642</td>
#       <td id="T_27450_row1_col2" class="data row1 col2" >12.987453</td>
#       <td id="T_27450_row1_col3" class="data row1 col3" >6.346338</td>
#       <td id="T_27450_row1_col4" class="data row1 col4" >25.149470</td>
#       <td id="T_27450_row1_col5" class="data row1 col5" >7.487364</td>
#       <td id="T_27450_row1_col6" class="data row1 col6" >19.549433</td>
#       <td id="T_27450_row1_col7" class="data row1 col7" >19.777709</td>
#       <td id="T_27450_row1_col8" class="data row1 col8" >27.165711</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_6333a_row0_col0, #T_6333a_row0_col6, #T_6333a_row1_col1, #T_6333a_row1_col2, #T_6333a_row1_col3, #T_6333a_row1_col4, #T_6333a_row1_col5, #T_6333a_row1_col7, #T_6333a_row1_col8 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_6333a_row0_col1, #T_6333a_row0_col2, #T_6333a_row0_col3, #T_6333a_row0_col4, #T_6333a_row0_col5, #T_6333a_row0_col7, #T_6333a_row0_col8, #T_6333a_row1_col0, #T_6333a_row1_col6 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# </style>
# <table id="T_6333a">
#   <caption>Pesos</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6333a_level0_col0" class="col_heading level0 col0" >ABEV3.SA</th>
#       <th id="T_6333a_level0_col1" class="col_heading level0 col1" >CSUD3.SA</th>
#       <th id="T_6333a_level0_col2" class="col_heading level0 col2" >FLRY3.SA</th>
#       <th id="T_6333a_level0_col3" class="col_heading level0 col3" >GGBR4.SA</th>
#       <th id="T_6333a_level0_col4" class="col_heading level0 col4" >PSSA3.SA</th>
#       <th id="T_6333a_level0_col5" class="col_heading level0 col5" >RENT3.SA</th>
#       <th id="T_6333a_level0_col6" class="col_heading level0 col6" >VALE3.SA</th>
#       <th id="T_6333a_level0_col7" class="col_heading level0 col7" >VIVT3.SA</th>
#       <th id="T_6333a_level0_col8" class="col_heading level0 col8" >WEGE3.SA</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6333a_level0_row0" class="row_heading level0 row0" >Pesos</th>
#       <td id="T_6333a_row0_col0" class="data row0 col0" >30.149550</td>
#       <td id="T_6333a_row0_col1" class="data row0 col1" >3.814796</td>
#       <td id="T_6333a_row0_col2" class="data row0 col2" >10.259881</td>
#       <td id="T_6333a_row0_col3" class="data row0 col3" >0.752380</td>
#       <td id="T_6333a_row0_col4" class="data row0 col4" >9.829548</td>
#       <td id="T_6333a_row0_col5" class="data row0 col5" >0.140752</td>
#       <td id="T_6333a_row0_col6" class="data row0 col6" >21.337697</td>
#       <td id="T_6333a_row0_col7" class="data row0 col7" >15.985690</td>
#       <td id="T_6333a_row0_col8" class="data row0 col8" >7.729707</td>
#     </tr>
#     <tr>
#       <th id="T_6333a_level0_row1" class="row_heading level0 row1" >retornos markwitz em %</th>
#       <td id="T_6333a_row1_col0" class="data row1 col0" >15.098473</td>
#       <td id="T_6333a_row1_col1" class="data row1 col1" >21.666692</td>
#       <td id="T_6333a_row1_col2" class="data row1 col2" >12.987480</td>
#       <td id="T_6333a_row1_col3" class="data row1 col3" >6.346311</td>
#       <td id="T_6333a_row1_col4" class="data row1 col4" >25.149490</td>
#       <td id="T_6333a_row1_col5" class="data row1 col5" >27.165688</td>
#       <td id="T_6333a_row1_col6" class="data row1 col6" >7.487362</td>
#       <td id="T_6333a_row1_col7" class="data row1 col7" >19.777781</td>
#       <td id="T_6333a_row1_col8" class="data row1 col8" >19.549368</td>
#     </tr>
#   </tbody>
# </table>
# ****************************************
# **O retorno da carteira para o período: 2017-09-30**
# <style type="text/css">
# #T_7ebcb_row0_col0, #T_7ebcb_row0_col1, #T_7ebcb_row0_col2, #T_7ebcb_row0_col3, #T_7ebcb_row1_col4 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_7ebcb_row0_col4, #T_7ebcb_row1_col0, #T_7ebcb_row1_col1, #T_7ebcb_row1_col2, #T_7ebcb_row1_col3 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# </style>
# <table id="T_7ebcb">
#   <caption>Pesos</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7ebcb_level0_col0" class="col_heading level0 col0" >ABEV3.SA</th>
#       <th id="T_7ebcb_level0_col1" class="col_heading level0 col1" >MDIA3.SA</th>
#       <th id="T_7ebcb_level0_col2" class="col_heading level0 col2" >VIVT3.SA</th>
#       <th id="T_7ebcb_level0_col3" class="col_heading level0 col3" >WEGE3.SA</th>
#       <th id="T_7ebcb_level0_col4" class="col_heading level0 col4" >BRAP4.SA</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7ebcb_level0_row0" class="row_heading level0 row0" >Pesos</th>
#       <td id="T_7ebcb_row0_col0" class="data row0 col0" >20.000000</td>
#       <td id="T_7ebcb_row0_col1" class="data row0 col1" >20.000000</td>
#       <td id="T_7ebcb_row0_col2" class="data row0 col2" >20.000000</td>
#       <td id="T_7ebcb_row0_col3" class="data row0 col3" >20.000000</td>
#       <td id="T_7ebcb_row0_col4" class="data row0 col4" >20.000000</td>
#     </tr>
#     <tr>
#       <th id="T_7ebcb_level0_row1" class="row_heading level0 row1" >retornos em %</th>
#       <td id="T_7ebcb_row1_col0" class="data row1 col0" >0.841414</td>
#       <td id="T_7ebcb_row1_col1" class="data row1 col1" >5.745184</td>
#       <td id="T_7ebcb_row1_col2" class="data row1 col2" >-5.159663</td>
#       <td id="T_7ebcb_row1_col3" class="data row1 col3" >9.359409</td>
#       <td id="T_7ebcb_row1_col4" class="data row1 col4" >23.077732</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_c53bd_row0_col0, #T_c53bd_row0_col2, #T_c53bd_row0_col3, #T_c53bd_row0_col4, #T_c53bd_row1_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_c53bd_row0_col1, #T_c53bd_row1_col0, #T_c53bd_row1_col2, #T_c53bd_row1_col3, #T_c53bd_row1_col4 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# </style>
# <table id="T_c53bd">
#   <caption>Pesos</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c53bd_level0_col0" class="col_heading level0 col0" >ABEV3.SA</th>
#       <th id="T_c53bd_level0_col1" class="col_heading level0 col1" >BRAP4.SA</th>
#       <th id="T_c53bd_level0_col2" class="col_heading level0 col2" >MDIA3.SA</th>
#       <th id="T_c53bd_level0_col3" class="col_heading level0 col3" >VIVT3.SA</th>
#       <th id="T_c53bd_level0_col4" class="col_heading level0 col4" >WEGE3.SA</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c53bd_level0_row0" class="row_heading level0 row0" >Pesos</th>
#       <td id="T_c53bd_row0_col0" class="data row0 col0" >25.037390</td>
#       <td id="T_c53bd_row0_col1" class="data row0 col1" >18.647732</td>
#       <td id="T_c53bd_row0_col2" class="data row0 col2" >8.821981</td>
#       <td id="T_c53bd_row0_col3" class="data row0 col3" >34.010216</td>
#       <td id="T_c53bd_row0_col4" class="data row0 col4" >13.482682</td>
#     </tr>
#     <tr>
#       <th id="T_c53bd_level0_row1" class="row_heading level0 row1" >retornos markwitz em %</th>
#       <td id="T_c53bd_row1_col0" class="data row1 col0" >0.841426</td>
#       <td id="T_c53bd_row1_col1" class="data row1 col1" >23.077743</td>
#       <td id="T_c53bd_row1_col2" class="data row1 col2" >5.745192</td>
#       <td id="T_c53bd_row1_col3" class="data row1 col3" >-5.159700</td>
#       <td id="T_c53bd_row1_col4" class="data row1 col4" >9.359423</td>
#     </tr>
#   </tbody>
# </table>
# ****************************************
# **O retorno da carteira para o período: 2017-12-31**
# C:\Users\jefer\AppData\Local\Temp\ipykernel_4584\1529076990.py:26: RuntimeWarning: invalid value encountered in scalar divide
#   lambda x: (x.iloc[-1] - x.iloc[0]) / x.iloc[0] * 100
# <style type="text/css">
# #T_fad2f_row0_col0, #T_fad2f_row0_col1, #T_fad2f_row0_col2, #T_fad2f_row0_col6, #T_fad2f_row1_col3, #T_fad2f_row1_col4, #T_fad2f_row1_col5 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_fad2f_row0_col3, #T_fad2f_row0_col4, #T_fad2f_row0_col5, #T_fad2f_row1_col0, #T_fad2f_row1_col1, #T_fad2f_row1_col2, #T_fad2f_row1_col6 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# </style>
# <table id="T_fad2f">
#   <caption>Pesos</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fad2f_level0_col0" class="col_heading level0 col0" >VALE3.SA</th>
#       <th id="T_fad2f_level0_col1" class="col_heading level0 col1" >WEGE3.SA</th>
#       <th id="T_fad2f_level0_col2" class="col_heading level0 col2" >ABEV3.SA</th>
#       <th id="T_fad2f_level0_col3" class="col_heading level0 col3" >PSSA3.SA</th>
#       <th id="T_fad2f_level0_col4" class="col_heading level0 col4" >CSUD3.SA</th>
#       <th id="T_fad2f_level0_col5" class="col_heading level0 col5" >MGLU3.SA</th>
#       <th id="T_fad2f_level0_col6" class="col_heading level0 col6" >VIVT3.SA</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fad2f_level0_row0" class="row_heading level0 row0" >Pesos</th>
#       <td id="T_fad2f_row0_col0" class="data row0 col0" >19.047619</td>
#       <td id="T_fad2f_row0_col1" class="data row0 col1" >19.047619</td>
#       <td id="T_fad2f_row0_col2" class="data row0 col2" >14.285714</td>
#       <td id="T_fad2f_row0_col3" class="data row0 col3" >14.285714</td>
#       <td id="T_fad2f_row0_col4" class="data row0 col4" >14.285714</td>
#       <td id="T_fad2f_row0_col5" class="data row0 col5" >8.571429</td>
#       <td id="T_fad2f_row0_col6" class="data row0 col6" >10.476190</td>
#     </tr>
#     <tr>
#       <th id="T_fad2f_level0_row1" class="row_heading level0 row1" >retornos em %</th>
#       <td id="T_fad2f_row1_col0" class="data row1 col0" >2.940711</td>
#       <td id="T_fad2f_row1_col1" class="data row1 col1" >-7.701557</td>
#       <td id="T_fad2f_row1_col2" class="data row1 col2" >11.071806</td>
#       <td id="T_fad2f_row1_col3" class="data row1 col3" >31.030797</td>
#       <td id="T_fad2f_row1_col4" class="data row1 col4" >14.975844</td>
#       <td id="T_fad2f_row1_col5" class="data row1 col5" >25.044731</td>
#       <td id="T_fad2f_row1_col6" class="data row1 col6" >9.950266</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_45340_row0_col0, #T_45340_row0_col4, #T_45340_row0_col5, #T_45340_row0_col6, #T_45340_row1_col1, #T_45340_row1_col3 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_45340_row0_col1, #T_45340_row0_col2, #T_45340_row0_col3, #T_45340_row1_col0, #T_45340_row1_col2, #T_45340_row1_col4, #T_45340_row1_col5, #T_45340_row1_col6 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# </style>
# <table id="T_45340">
#   <caption>Pesos</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_45340_level0_col0" class="col_heading level0 col0" >ABEV3.SA</th>
#       <th id="T_45340_level0_col1" class="col_heading level0 col1" >CSUD3.SA</th>
#       <th id="T_45340_level0_col2" class="col_heading level0 col2" >MGLU3.SA</th>
#       <th id="T_45340_level0_col3" class="col_heading level0 col3" >PSSA3.SA</th>
#       <th id="T_45340_level0_col4" class="col_heading level0 col4" >VALE3.SA</th>
#       <th id="T_45340_level0_col5" class="col_heading level0 col5" >VIVT3.SA</th>
#       <th id="T_45340_level0_col6" class="col_heading level0 col6" >WEGE3.SA</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_45340_level0_row0" class="row_heading level0 row0" >Pesos</th>
#       <td id="T_45340_row0_col0" class="data row0 col0" >17.886720</td>
#       <td id="T_45340_row0_col1" class="data row0 col1" >6.126371</td>
#       <td id="T_45340_row0_col2" class="data row0 col2" >0.000000</td>
#       <td id="T_45340_row0_col3" class="data row0 col3" >23.842604</td>
#       <td id="T_45340_row0_col4" class="data row0 col4" >14.528933</td>
#       <td id="T_45340_row0_col5" class="data row0 col5" >28.005379</td>
#       <td id="T_45340_row0_col6" class="data row0 col6" >9.609993</td>
#     </tr>
#     <tr>
#       <th id="T_45340_level0_row1" class="row_heading level0 row1" >retornos markwitz em %</th>
#       <td id="T_45340_row1_col0" class="data row1 col0" >11.071776</td>
#       <td id="T_45340_row1_col1" class="data row1 col1" >14.975807</td>
#       <td id="T_45340_row1_col2" class="data row1 col2" >nan</td>
#       <td id="T_45340_row1_col3" class="data row1 col3" >31.030763</td>
#       <td id="T_45340_row1_col4" class="data row1 col4" >2.940755</td>
#       <td id="T_45340_row1_col5" class="data row1 col5" >9.950264</td>
#       <td id="T_45340_row1_col6" class="data row1 col6" >-7.701535</td>
#     </tr>
#   </tbody>
# </table>
# ****************************************
# **O retorno da carteira para o período: 2018-03-31**
# C:\Users\jefer\AppData\Local\Temp\ipykernel_4584\1529076990.py:26: RuntimeWarning: invalid value encountered in scalar divide
#   lambda x: (x.iloc[-1] - x.iloc[0]) / x.iloc[0] * 100
# <style type="text/css">
# #T_d1fe3_row0_col0, #T_d1fe3_row0_col1, #T_d1fe3_row0_col2, #T_d1fe3_row0_col3, #T_d1fe3_row0_col4, #T_d1fe3_row0_col5 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_d1fe3_row0_col6, #T_d1fe3_row1_col0, #T_d1fe3_row1_col1, #T_d1fe3_row1_col2, #T_d1fe3_row1_col3, #T_d1fe3_row1_col4, #T_d1fe3_row1_col5, #T_d1fe3_row1_col6 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# </style>
# <table id="T_d1fe3">
#   <caption>Pesos</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d1fe3_level0_col0" class="col_heading level0 col0" >CSNA3.SA</th>
#       <th id="T_d1fe3_level0_col1" class="col_heading level0 col1" >CGAS3.SA</th>
#       <th id="T_d1fe3_level0_col2" class="col_heading level0 col2" >EGIE3.SA</th>
#       <th id="T_d1fe3_level0_col3" class="col_heading level0 col3" >VIVT3.SA</th>
#       <th id="T_d1fe3_level0_col4" class="col_heading level0 col4" >MDIA3.SA</th>
#       <th id="T_d1fe3_level0_col5" class="col_heading level0 col5" >CSUD3.SA</th>
#       <th id="T_d1fe3_level0_col6" class="col_heading level0 col6" >WEGE3.SA</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d1fe3_level0_row0" class="row_heading level0 row0" >Pesos</th>
#       <td id="T_d1fe3_row0_col0" class="data row0 col0" >20.000000</td>
#       <td id="T_d1fe3_row0_col1" class="data row0 col1" >20.000000</td>
#       <td id="T_d1fe3_row0_col2" class="data row0 col2" >20.000000</td>
#       <td id="T_d1fe3_row0_col3" class="data row0 col3" >15.000000</td>
#       <td id="T_d1fe3_row0_col4" class="data row0 col4" >15.000000</td>
#       <td id="T_d1fe3_row0_col5" class="data row0 col5" >10.000000</td>
#       <td id="T_d1fe3_row0_col6" class="data row0 col6" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d1fe3_level0_row1" class="row_heading level0 row1" >retornos em %</th>
#       <td id="T_d1fe3_row1_col0" class="data row1 col0" >-10.580206</td>
#       <td id="T_d1fe3_row1_col1" class="data row1 col1" >-4.838708</td>
#       <td id="T_d1fe3_row1_col2" class="data row1 col2" >-4.849163</td>
#       <td id="T_d1fe3_row1_col3" class="data row1 col3" >-1.216884</td>
#       <td id="T_d1fe3_row1_col4" class="data row1 col4" >-26.305432</td>
#       <td id="T_d1fe3_row1_col5" class="data row1 col5" >-42.617763</td>
#       <td id="T_d1fe3_row1_col6" class="data row1 col6" >nan</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_b557e_row0_col0, #T_b557e_row0_col1, #T_b557e_row0_col2, #T_b557e_row0_col3, #T_b557e_row0_col4, #T_b557e_row0_col5, #T_b557e_row0_col6 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_b557e_row1_col0, #T_b557e_row1_col1, #T_b557e_row1_col2, #T_b557e_row1_col3, #T_b557e_row1_col4, #T_b557e_row1_col5, #T_b557e_row1_col6 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# </style>
# <table id="T_b557e">
#   <caption>Pesos</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b557e_level0_col0" class="col_heading level0 col0" >CGAS3.SA</th>
#       <th id="T_b557e_level0_col1" class="col_heading level0 col1" >CSNA3.SA</th>
#       <th id="T_b557e_level0_col2" class="col_heading level0 col2" >CSUD3.SA</th>
#       <th id="T_b557e_level0_col3" class="col_heading level0 col3" >EGIE3.SA</th>
#       <th id="T_b557e_level0_col4" class="col_heading level0 col4" >MDIA3.SA</th>
#       <th id="T_b557e_level0_col5" class="col_heading level0 col5" >VIVT3.SA</th>
#       <th id="T_b557e_level0_col6" class="col_heading level0 col6" >WEGE3.SA</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b557e_level0_row0" class="row_heading level0 row0" >Pesos</th>
#       <td id="T_b557e_row0_col0" class="data row0 col0" >13.486973</td>
#       <td id="T_b557e_row0_col1" class="data row0 col1" >1.229823</td>
#       <td id="T_b557e_row0_col2" class="data row0 col2" >7.669154</td>
#       <td id="T_b557e_row0_col3" class="data row0 col3" >30.714515</td>
#       <td id="T_b557e_row0_col4" class="data row0 col4" >5.155132</td>
#       <td id="T_b557e_row0_col5" class="data row0 col5" >27.541924</td>
#       <td id="T_b557e_row0_col6" class="data row0 col6" >14.202480</td>
#     </tr>
#     <tr>
#       <th id="T_b557e_level0_row1" class="row_heading level0 row1" >retornos markwitz em %</th>
#       <td id="T_b557e_row1_col0" class="data row1 col0" >-4.838726</td>
#       <td id="T_b557e_row1_col1" class="data row1 col1" >-10.580205</td>
#       <td id="T_b557e_row1_col2" class="data row1 col2" >-42.617766</td>
#       <td id="T_b557e_row1_col3" class="data row1 col3" >-4.849126</td>
#       <td id="T_b557e_row1_col4" class="data row1 col4" >-26.305392</td>
#       <td id="T_b557e_row1_col5" class="data row1 col5" >-1.216920</td>
#       <td id="T_b557e_row1_col6" class="data row1 col6" >-5.353953</td>
#     </tr>
#   </tbody>
# </table>
# ****************************************
# **O retorno da carteira para o período: 2018-06-30**
# <style type="text/css">
# #T_d5370_row0_col0, #T_d5370_row0_col2, #T_d5370_row0_col4, #T_d5370_row1_col1, #T_d5370_row1_col3, #T_d5370_row1_col5, #T_d5370_row1_col6, #T_d5370_row1_col7 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_d5370_row0_col1, #T_d5370_row0_col3, #T_d5370_row0_col5, #T_d5370_row0_col6, #T_d5370_row0_col7, #T_d5370_row1_col0, #T_d5370_row1_col2, #T_d5370_row1_col4 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# </style>
# <table id="T_d5370">
#   <caption>Pesos</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d5370_level0_col0" class="col_heading level0 col0" >ITUB4.SA</th>
#       <th id="T_d5370_level0_col1" class="col_heading level0 col1" >VALE3.SA</th>
#       <th id="T_d5370_level0_col2" class="col_heading level0 col2" >VIVT3.SA</th>
#       <th id="T_d5370_level0_col3" class="col_heading level0 col3" >WEGE3.SA</th>
#       <th id="T_d5370_level0_col4" class="col_heading level0 col4" >EGIE3.SA</th>
#       <th id="T_d5370_level0_col5" class="col_heading level0 col5" >B3SA3.SA</th>
#       <th id="T_d5370_level0_col6" class="col_heading level0 col6" >PRIO3.SA</th>
#       <th id="T_d5370_level0_col7" class="col_heading level0 col7" >BRAP4.SA</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d5370_level0_row0" class="row_heading level0 row0" >Pesos</th>
#       <td id="T_d5370_row0_col0" class="data row0 col0" >18.000000</td>
#       <td id="T_d5370_row0_col1" class="data row0 col1" >12.000000</td>
#       <td id="T_d5370_row0_col2" class="data row0 col2" >17.000000</td>
#       <td id="T_d5370_row0_col3" class="data row0 col3" >16.000000</td>
#       <td id="T_d5370_row0_col4" class="data row0 col4" >12.000000</td>
#       <td id="T_d5370_row0_col5" class="data row0 col5" >10.000000</td>
#       <td id="T_d5370_row0_col6" class="data row0 col6" >8.000000</td>
#       <td id="T_d5370_row0_col7" class="data row0 col7" >7.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d5370_level0_row1" class="row_heading level0 row1" >retornos em %</th>
#       <td id="T_d5370_row1_col0" class="data row1 col0" >8.822834</td>
#       <td id="T_d5370_row1_col1" class="data row1 col1" >28.324065</td>
#       <td id="T_d5370_row1_col2" class="data row1 col2" >-8.432990</td>
#       <td id="T_d5370_row1_col3" class="data row1 col3" >24.236220</td>
#       <td id="T_d5370_row1_col4" class="data row1 col4" >7.913297</td>
#       <td id="T_d5370_row1_col5" class="data row1 col5" >12.875947</td>
#       <td id="T_d5370_row1_col6" class="data row1 col6" >63.235294</td>
#       <td id="T_d5370_row1_col7" class="data row1 col7" >31.035708</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_8ce8d_row0_col0, #T_8ce8d_row0_col1, #T_8ce8d_row0_col3, #T_8ce8d_row0_col4, #T_8ce8d_row0_col5, #T_8ce8d_row0_col7, #T_8ce8d_row1_col2, #T_8ce8d_row1_col6 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_8ce8d_row0_col2, #T_8ce8d_row0_col6, #T_8ce8d_row1_col0, #T_8ce8d_row1_col1, #T_8ce8d_row1_col3, #T_8ce8d_row1_col4, #T_8ce8d_row1_col5, #T_8ce8d_row1_col7 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_8ce8d">
#   <caption>Pesos</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8ce8d_level0_col0" class="col_heading level0 col0" >B3SA3.SA</th>
#       <th id="T_8ce8d_level0_col1" class="col_heading level0 col1" >BRAP4.SA</th>
#       <th id="T_8ce8d_level0_col2" class="col_heading level0 col2" >EGIE3.SA</th>
#       <th id="T_8ce8d_level0_col3" class="col_heading level0 col3" >ITUB4.SA</th>
#       <th id="T_8ce8d_level0_col4" class="col_heading level0 col4" >PRIO3.SA</th>
#       <th id="T_8ce8d_level0_col5" class="col_heading level0 col5" >VALE3.SA</th>
#       <th id="T_8ce8d_level0_col6" class="col_heading level0 col6" >VIVT3.SA</th>
#       <th id="T_8ce8d_level0_col7" class="col_heading level0 col7" >WEGE3.SA</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8ce8d_level0_row0" class="row_heading level0 row0" >Pesos</th>
#       <td id="T_8ce8d_row0_col0" class="data row0 col0" >0.000000</td>
#       <td id="T_8ce8d_row0_col1" class="data row0 col1" >14.499333</td>
#       <td id="T_8ce8d_row0_col2" class="data row0 col2" >25.398860</td>
#       <td id="T_8ce8d_row0_col3" class="data row0 col3" >3.943505</td>
#       <td id="T_8ce8d_row0_col4" class="data row0 col4" >11.889022</td>
#       <td id="T_8ce8d_row0_col5" class="data row0 col5" >0.000000</td>
#       <td id="T_8ce8d_row0_col6" class="data row0 col6" >24.002807</td>
#       <td id="T_8ce8d_row0_col7" class="data row0 col7" >20.266472</td>
#     </tr>
#     <tr>
#       <th id="T_8ce8d_level0_row1" class="row_heading level0 row1" >retornos markwitz em %</th>
#       <td id="T_8ce8d_row1_col0" class="data row1 col0" >12.875927</td>
#       <td id="T_8ce8d_row1_col1" class="data row1 col1" >31.035700</td>
#       <td id="T_8ce8d_row1_col2" class="data row1 col2" >7.913282</td>
#       <td id="T_8ce8d_row1_col3" class="data row1 col3" >8.822807</td>
#       <td id="T_8ce8d_row1_col4" class="data row1 col4" >63.235294</td>
#       <td id="T_8ce8d_row1_col5" class="data row1 col5" >28.324056</td>
#       <td id="T_8ce8d_row1_col6" class="data row1 col6" >-8.432917</td>
#       <td id="T_8ce8d_row1_col7" class="data row1 col7" >24.236247</td>
#     </tr>
#   </tbody>
# </table>
# ****************************************
# **O retorno da carteira para o período: 2018-09-30**
# C:\Users\jefer\AppData\Local\Temp\ipykernel_4584\1529076990.py:26: RuntimeWarning: invalid value encountered in scalar divide
#   lambda x: (x.iloc[-1] - x.iloc[0]) / x.iloc[0] * 100
# <style type="text/css">
# #T_029c9_row0_col0, #T_029c9_row0_col1, #T_029c9_row0_col2, #T_029c9_row0_col3, #T_029c9_row0_col5, #T_029c9_row0_col6, #T_029c9_row1_col4, #T_029c9_row1_col7 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_029c9_row0_col4, #T_029c9_row0_col7, #T_029c9_row1_col0, #T_029c9_row1_col1, #T_029c9_row1_col2, #T_029c9_row1_col3, #T_029c9_row1_col5, #T_029c9_row1_col6 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# </style>
# <table id="T_029c9">
#   <caption>Pesos</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_029c9_level0_col0" class="col_heading level0 col0" >BRKM5.SA</th>
#       <th id="T_029c9_level0_col1" class="col_heading level0 col1" >WEGE3.SA</th>
#       <th id="T_029c9_level0_col2" class="col_heading level0 col2" >FLRY3.SA</th>
#       <th id="T_029c9_level0_col3" class="col_heading level0 col3" >VALE3.SA</th>
#       <th id="T_029c9_level0_col4" class="col_heading level0 col4" >EGIE3.SA</th>
#       <th id="T_029c9_level0_col5" class="col_heading level0 col5" >ABEV3.SA</th>
#       <th id="T_029c9_level0_col6" class="col_heading level0 col6" >PSSA3.SA</th>
#       <th id="T_029c9_level0_col7" class="col_heading level0 col7" >IRBR3.SA</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_029c9_level0_row0" class="row_heading level0 row0" >Pesos</th>
#       <td id="T_029c9_row0_col0" class="data row0 col0" >20.000000</td>
#       <td id="T_029c9_row0_col1" class="data row0 col1" >18.000000</td>
#       <td id="T_029c9_row0_col2" class="data row0 col2" >16.000000</td>
#       <td id="T_029c9_row0_col3" class="data row0 col3" >15.000000</td>
#       <td id="T_029c9_row0_col4" class="data row0 col4" >12.000000</td>
#       <td id="T_029c9_row0_col5" class="data row0 col5" >9.000000</td>
#       <td id="T_029c9_row0_col6" class="data row0 col6" >7.000000</td>
#       <td id="T_029c9_row0_col7" class="data row0 col7" >3.000000</td>
#     </tr>
#     <tr>
#       <th id="T_029c9_level0_row1" class="row_heading level0 row1" >retornos em %</th>
#       <td id="T_029c9_row1_col0" class="data row1 col0" >-16.584494</td>
#       <td id="T_029c9_row1_col1" class="data row1 col1" >-10.880709</td>
#       <td id="T_029c9_row1_col2" class="data row1 col2" >-9.390764</td>
#       <td id="T_029c9_row1_col3" class="data row1 col3" >-16.666680</td>
#       <td id="T_029c9_row1_col4" class="data row1 col4" >22.206583</td>
#       <td id="T_029c9_row1_col5" class="data row1 col5" >-13.992883</td>
#       <td id="T_029c9_row1_col6" class="data row1 col6" >-12.291429</td>
#       <td id="T_029c9_row1_col7" class="data row1 col7" >25.215780</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_21018_row0_col0, #T_21018_row0_col1, #T_21018_row0_col2, #T_21018_row0_col3, #T_21018_row0_col5, #T_21018_row0_col6, #T_21018_row1_col4 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_21018_row0_col4, #T_21018_row0_col7, #T_21018_row1_col0, #T_21018_row1_col1, #T_21018_row1_col2, #T_21018_row1_col3, #T_21018_row1_col5, #T_21018_row1_col6, #T_21018_row1_col7 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# </style>
# <table id="T_21018">
#   <caption>Pesos</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_21018_level0_col0" class="col_heading level0 col0" >ABEV3.SA</th>
#       <th id="T_21018_level0_col1" class="col_heading level0 col1" >BRKM5.SA</th>
#       <th id="T_21018_level0_col2" class="col_heading level0 col2" >EGIE3.SA</th>
#       <th id="T_21018_level0_col3" class="col_heading level0 col3" >FLRY3.SA</th>
#       <th id="T_21018_level0_col4" class="col_heading level0 col4" >IRBR3.SA</th>
#       <th id="T_21018_level0_col5" class="col_heading level0 col5" >PSSA3.SA</th>
#       <th id="T_21018_level0_col6" class="col_heading level0 col6" >VALE3.SA</th>
#       <th id="T_21018_level0_col7" class="col_heading level0 col7" >WEGE3.SA</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_21018_level0_row0" class="row_heading level0 row0" >Pesos</th>
#       <td id="T_21018_row0_col0" class="data row0 col0" >29.399644</td>
#       <td id="T_21018_row0_col1" class="data row0 col1" >4.896270</td>
#       <td id="T_21018_row0_col2" class="data row0 col2" >24.391036</td>
#       <td id="T_21018_row0_col3" class="data row0 col3" >13.493386</td>
#       <td id="T_21018_row0_col4" class="data row0 col4" >4.824101</td>
#       <td id="T_21018_row0_col5" class="data row0 col5" >15.190400</td>
#       <td id="T_21018_row0_col6" class="data row0 col6" >7.805162</td>
#       <td id="T_21018_row0_col7" class="data row0 col7" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_21018_level0_row1" class="row_heading level0 row1" >retornos markwitz em %</th>
#       <td id="T_21018_row1_col0" class="data row1 col0" >-13.992896</td>
#       <td id="T_21018_row1_col1" class="data row1 col1" >-16.584503</td>
#       <td id="T_21018_row1_col2" class="data row1 col2" >22.206560</td>
#       <td id="T_21018_row1_col3" class="data row1 col3" >-9.390752</td>
#       <td id="T_21018_row1_col4" class="data row1 col4" >25.215767</td>
#       <td id="T_21018_row1_col5" class="data row1 col5" >-12.291445</td>
#       <td id="T_21018_row1_col6" class="data row1 col6" >-16.666671</td>
#       <td id="T_21018_row1_col7" class="data row1 col7" >nan</td>
#     </tr>
#   </tbody>
# </table>
# ****************************************
# **O retorno da carteira para o período: 2018-12-31**
# <style type="text/css">
# #T_4b033_row0_col0, #T_4b033_row0_col1, #T_4b033_row0_col2, #T_4b033_row0_col4, #T_4b033_row0_col5, #T_4b033_row1_col3 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_4b033_row0_col3, #T_4b033_row1_col0, #T_4b033_row1_col1, #T_4b033_row1_col2, #T_4b033_row1_col4, #T_4b033_row1_col5 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# </style>
# <table id="T_4b033">
#   <caption>Pesos</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4b033_level0_col0" class="col_heading level0 col0" >LREN3.SA</th>
#       <th id="T_4b033_level0_col1" class="col_heading level0 col1" >WEGE3.SA</th>
#       <th id="T_4b033_level0_col2" class="col_heading level0 col2" >MRVE3.SA</th>
#       <th id="T_4b033_level0_col3" class="col_heading level0 col3" >CGAS3.SA</th>
#       <th id="T_4b033_level0_col4" class="col_heading level0 col4" >ABEV3.SA</th>
#       <th id="T_4b033_level0_col5" class="col_heading level0 col5" >PSSA3.SA</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4b033_level0_row0" class="row_heading level0 row0" >Pesos</th>
#       <td id="T_4b033_row0_col0" class="data row0 col0" >20.000000</td>
#       <td id="T_4b033_row0_col1" class="data row0 col1" >15.000000</td>
#       <td id="T_4b033_row0_col2" class="data row0 col2" >15.000000</td>
#       <td id="T_4b033_row0_col3" class="data row0 col3" >10.000000</td>
#       <td id="T_4b033_row0_col4" class="data row0 col4" >15.000000</td>
#       <td id="T_4b033_row0_col5" class="data row0 col5" >25.000000</td>
#     </tr>
#     <tr>
#       <th id="T_4b033_level0_row1" class="row_heading level0 row1" >retornos em %</th>
#       <td id="T_4b033_row1_col0" class="data row1 col0" >2.080815</td>
#       <td id="T_4b033_row1_col1" class="data row1 col1" >-1.441834</td>
#       <td id="T_4b033_row1_col2" class="data row1 col2" >10.768011</td>
#       <td id="T_4b033_row1_col3" class="data row1 col3" >21.904530</td>
#       <td id="T_4b033_row1_col4" class="data row1 col4" >3.061852</td>
#       <td id="T_4b033_row1_col5" class="data row1 col5" >6.890420</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_3dbe8_row0_col0, #T_3dbe8_row0_col2, #T_3dbe8_row0_col4, #T_3dbe8_row0_col5, #T_3dbe8_row1_col1, #T_3dbe8_row1_col3 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_3dbe8_row0_col1, #T_3dbe8_row0_col3, #T_3dbe8_row1_col0, #T_3dbe8_row1_col2, #T_3dbe8_row1_col4, #T_3dbe8_row1_col5 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# </style>
# <table id="T_3dbe8">
#   <caption>Pesos</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3dbe8_level0_col0" class="col_heading level0 col0" >ABEV3.SA</th>
#       <th id="T_3dbe8_level0_col1" class="col_heading level0 col1" >CGAS3.SA</th>
#       <th id="T_3dbe8_level0_col2" class="col_heading level0 col2" >LREN3.SA</th>
#       <th id="T_3dbe8_level0_col3" class="col_heading level0 col3" >MRVE3.SA</th>
#       <th id="T_3dbe8_level0_col4" class="col_heading level0 col4" >PSSA3.SA</th>
#       <th id="T_3dbe8_level0_col5" class="col_heading level0 col5" >WEGE3.SA</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3dbe8_level0_row0" class="row_heading level0 row0" >Pesos</th>
#       <td id="T_3dbe8_row0_col0" class="data row0 col0" >39.091289</td>
#       <td id="T_3dbe8_row0_col1" class="data row0 col1" >13.188516</td>
#       <td id="T_3dbe8_row0_col2" class="data row0 col2" >2.213871</td>
#       <td id="T_3dbe8_row0_col3" class="data row0 col3" >0.000000</td>
#       <td id="T_3dbe8_row0_col4" class="data row0 col4" >34.397874</td>
#       <td id="T_3dbe8_row0_col5" class="data row0 col5" >11.108450</td>
#     </tr>
#     <tr>
#       <th id="T_3dbe8_level0_row1" class="row_heading level0 row1" >retornos markwitz em %</th>
#       <td id="T_3dbe8_row1_col0" class="data row1 col0" >3.061844</td>
#       <td id="T_3dbe8_row1_col1" class="data row1 col1" >21.904519</td>
#       <td id="T_3dbe8_row1_col2" class="data row1 col2" >2.080785</td>
#       <td id="T_3dbe8_row1_col3" class="data row1 col3" >10.768020</td>
#       <td id="T_3dbe8_row1_col4" class="data row1 col4" >6.890400</td>
#       <td id="T_3dbe8_row1_col5" class="data row1 col5" >-1.441764</td>
#     </tr>
#   </tbody>
# </table>
# ****************************************
# **O retorno da carteira para o período: 2019-03-31**
# <style type="text/css">
# #T_8e203_row0_col0, #T_8e203_row0_col1, #T_8e203_row0_col2, #T_8e203_row0_col3, #T_8e203_row0_col4, #T_8e203_row1_col5 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_8e203_row0_col5, #T_8e203_row1_col0, #T_8e203_row1_col1, #T_8e203_row1_col2, #T_8e203_row1_col3, #T_8e203_row1_col4 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# </style>
# <table id="T_8e203">
#   <caption>Pesos</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8e203_level0_col0" class="col_heading level0 col0" >ABEV3.SA</th>
#       <th id="T_8e203_level0_col1" class="col_heading level0 col1" >ITUB4.SA</th>
#       <th id="T_8e203_level0_col2" class="col_heading level0 col2" >BBDC4.SA</th>
#       <th id="T_8e203_level0_col3" class="col_heading level0 col3" >VIVT3.SA</th>
#       <th id="T_8e203_level0_col4" class="col_heading level0 col4" >BRKM5.SA</th>
#       <th id="T_8e203_level0_col5" class="col_heading level0 col5" >WEGE3.SA</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8e203_level0_row0" class="row_heading level0 row0" >Pesos</th>
#       <td id="T_8e203_row0_col0" class="data row0 col0" >18.341667</td>
#       <td id="T_8e203_row0_col1" class="data row0 col1" >19.241667</td>
#       <td id="T_8e203_row0_col2" class="data row0 col2" >19.241667</td>
#       <td id="T_8e203_row0_col3" class="data row0 col3" >19.241667</td>
#       <td id="T_8e203_row0_col4" class="data row0 col4" >11.271667</td>
#       <td id="T_8e203_row0_col5" class="data row0 col5" >12.671667</td>
#     </tr>
#     <tr>
#       <th id="T_8e203_level0_row1" class="row_heading level0 row1" >retornos em %</th>
#       <td id="T_8e203_row1_col0" class="data row1 col0" >6.678592</td>
#       <td id="T_8e203_row1_col1" class="data row1 col1" >7.946588</td>
#       <td id="T_8e203_row1_col2" class="data row1 col2" >6.152176</td>
#       <td id="T_8e203_row1_col3" class="data row1 col3" >-0.506839</td>
#       <td id="T_8e203_row1_col4" class="data row1 col4" >-29.517103</td>
#       <td id="T_8e203_row1_col5" class="data row1 col5" >17.041116</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_26d34_row0_col0, #T_26d34_row0_col1, #T_26d34_row0_col2, #T_26d34_row0_col4, #T_26d34_row1_col3, #T_26d34_row1_col5 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_26d34_row0_col3, #T_26d34_row0_col5, #T_26d34_row1_col0, #T_26d34_row1_col1, #T_26d34_row1_col2, #T_26d34_row1_col4 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# </style>
# <table id="T_26d34">
#   <caption>Pesos</caption>
# ...
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_35896_level0_col0" class="col_heading level0 col0" >ABEV3.SA</th>
#       <th id="T_35896_level0_col1" class="col_heading level0 col1" >FLRY3.SA</th>
#       <th id="T_35896_level0_col2" class="col_heading level0 col2" >ITUB4.SA</th>
#       <th id="T_35896_level0_col3" class="col_heading level0 col3" >MDIA3.SA</th>
#       <th id="T_35896_level0_col4" class="col_heading level0 col4" >VALE3.SA</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_35896_level0_row0" class="row_heading level0 row0" >Pesos</th>
#       <td id="T_35896_row0_col0" class="data row0 col0" >18.072289</td>
#       <td id="T_35896_row0_col1" class="data row0 col1" >21.686747</td>
#       <td id="T_35896_row0_col2" class="data row0 col2" >20.481928</td>
#       <td id="T_35896_row0_col3" class="data row0 col3" >19.879518</td>
#       <td id="T_35896_row0_col4" class="data row0 col4" >19.879518</td>
#     </tr>
#     <tr>
#       <th id="T_35896_level0_row1" class="row_heading level0 row1" >retornos em %</th>
#       <td id="T_35896_row1_col0" class="data row1 col0" >5.176719</td>
#       <td id="T_35896_row1_col1" class="data row1 col1" >-17.802616</td>
#       <td id="T_35896_row1_col2" class="data row1 col2" >4.134364</td>
#       <td id="T_35896_row1_col3" class="data row1 col3" >-9.314309</td>
#       <td id="T_35896_row1_col4" class="data row1 col4" >-5.452332</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_95b66_row0_col0, #T_95b66_row0_col1, #T_95b66_row0_col2, #T_95b66_row0_col3, #T_95b66_row0_col4 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_95b66_row1_col0, #T_95b66_row1_col1, #T_95b66_row1_col2, #T_95b66_row1_col3, #T_95b66_row1_col4 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# </style>
# <table id="T_95b66">
#   <caption>Pesos</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_95b66_level0_col0" class="col_heading level0 col0" >ABEV3.SA</th>
#       <th id="T_95b66_level0_col1" class="col_heading level0 col1" >FLRY3.SA</th>
#       <th id="T_95b66_level0_col2" class="col_heading level0 col2" >ITUB4.SA</th>
#       <th id="T_95b66_level0_col3" class="col_heading level0 col3" >MDIA3.SA</th>
#       <th id="T_95b66_level0_col4" class="col_heading level0 col4" >VALE3.SA</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_95b66_level0_row0" class="row_heading level0 row0" >Pesos</th>
#       <td id="T_95b66_row0_col0" class="data row0 col0" >30.528802</td>
#       <td id="T_95b66_row0_col1" class="data row0 col1" >17.103824</td>
#       <td id="T_95b66_row0_col2" class="data row0 col2" >12.647798</td>
#       <td id="T_95b66_row0_col3" class="data row0 col3" >12.727182</td>
#       <td id="T_95b66_row0_col4" class="data row0 col4" >26.992393</td>
#     </tr>
#     <tr>
#       <th id="T_95b66_level0_row1" class="row_heading level0 row1" >retornos markwitz em %</th>
#       <td id="T_95b66_row1_col0" class="data row1 col0" >5.176719</td>
#       <td id="T_95b66_row1_col1" class="data row1 col1" >-17.802614</td>
#       <td id="T_95b66_row1_col2" class="data row1 col2" >4.134322</td>
#       <td id="T_95b66_row1_col3" class="data row1 col3" >-9.314316</td>
#       <td id="T_95b66_row1_col4" class="data row1 col4" >-5.452332</td>
#     </tr>
#   </tbody>
# </table>
# ****************************************
# **O retorno da carteira para o período: 2025-03-31**
# <style type="text/css">
# #T_6fa0c_row0_col0, #T_6fa0c_row0_col1, #T_6fa0c_row0_col2, #T_6fa0c_row0_col4, #T_6fa0c_row0_col5, #T_6fa0c_row1_col3 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_6fa0c_row0_col3, #T_6fa0c_row1_col0, #T_6fa0c_row1_col1, #T_6fa0c_row1_col2, #T_6fa0c_row1_col4, #T_6fa0c_row1_col5 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# </style>
# <table id="T_6fa0c">
#   <caption>Pesos</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6fa0c_level0_col0" class="col_heading level0 col0" >VIVT3.SA</th>
#       <th id="T_6fa0c_level0_col1" class="col_heading level0 col1" >WEGE3.SA</th>
#       <th id="T_6fa0c_level0_col2" class="col_heading level0 col2" >FLRY3.SA</th>
#       <th id="T_6fa0c_level0_col3" class="col_heading level0 col3" >EGIE3.SA</th>
#       <th id="T_6fa0c_level0_col4" class="col_heading level0 col4" >VALE3.SA</th>
#       <th id="T_6fa0c_level0_col5" class="col_heading level0 col5" >BRKM5.SA</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6fa0c_level0_row0" class="row_heading level0 row0" >Pesos</th>
#       <td id="T_6fa0c_row0_col0" class="data row0 col0" >20.000000</td>
#       <td id="T_6fa0c_row0_col1" class="data row0 col1" >20.000000</td>
#       <td id="T_6fa0c_row0_col2" class="data row0 col2" >18.000000</td>
#       <td id="T_6fa0c_row0_col3" class="data row0 col3" >15.000000</td>
#       <td id="T_6fa0c_row0_col4" class="data row0 col4" >12.000000</td>
#       <td id="T_6fa0c_row0_col5" class="data row0 col5" >15.000000</td>
#     </tr>
#     <tr>
#       <th id="T_6fa0c_level0_row1" class="row_heading level0 row1" >retornos em %</th>
#       <td id="T_6fa0c_row1_col0" class="data row1 col0" >17.485961</td>
#       <td id="T_6fa0c_row1_col1" class="data row1 col1" >-6.403798</td>
#       <td id="T_6fa0c_row1_col2" class="data row1 col2" >8.803419</td>
#       <td id="T_6fa0c_row1_col3" class="data row1 col3" >19.843300</td>
#       <td id="T_6fa0c_row1_col4" class="data row1 col4" >-7.553773</td>
#       <td id="T_6fa0c_row1_col5" class="data row1 col5" >-15.819212</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_eea71_row0_col0, #T_eea71_row0_col1, #T_eea71_row0_col3, #T_eea71_row0_col4, #T_eea71_row0_col5, #T_eea71_row1_col2 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_eea71_row0_col2, #T_eea71_row1_col0, #T_eea71_row1_col1, #T_eea71_row1_col3, #T_eea71_row1_col4, #T_eea71_row1_col5 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# </style>
# <table id="T_eea71">
#   <caption>Pesos</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_eea71_level0_col0" class="col_heading level0 col0" >BRKM5.SA</th>
#       <th id="T_eea71_level0_col1" class="col_heading level0 col1" >EGIE3.SA</th>
#       <th id="T_eea71_level0_col2" class="col_heading level0 col2" >FLRY3.SA</th>
#       <th id="T_eea71_level0_col3" class="col_heading level0 col3" >VALE3.SA</th>
#       <th id="T_eea71_level0_col4" class="col_heading level0 col4" >VIVT3.SA</th>
#       <th id="T_eea71_level0_col5" class="col_heading level0 col5" >WEGE3.SA</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_eea71_level0_row0" class="row_heading level0 row0" >Pesos</th>
#       <td id="T_eea71_row0_col0" class="data row0 col0" >9.340163</td>
#       <td id="T_eea71_row0_col1" class="data row0 col1" >31.691917</td>
#       <td id="T_eea71_row0_col2" class="data row0 col2" >2.154335</td>
#       <td id="T_eea71_row0_col3" class="data row0 col3" >14.906604</td>
#       <td id="T_eea71_row0_col4" class="data row0 col4" >19.501876</td>
#       <td id="T_eea71_row0_col5" class="data row0 col5" >22.405104</td>
#     </tr>
#     <tr>
#       <th id="T_eea71_level0_row1" class="row_heading level0 row1" >retornos markwitz em %</th>
#       <td id="T_eea71_row1_col0" class="data row1 col0" >-15.819212</td>
#       <td id="T_eea71_row1_col1" class="data row1 col1" >19.843300</td>
#       <td id="T_eea71_row1_col2" class="data row1 col2" >8.803419</td>
#       <td id="T_eea71_row1_col3" class="data row1 col3" >-7.553773</td>
#       <td id="T_eea71_row1_col4" class="data row1 col4" >17.485978</td>
#       <td id="T_eea71_row1_col5" class="data row1 col5" >-6.403798</td>
#     </tr>
#   </tbody>
# </table>
# ****************************************
# **O retorno da carteira para o período: 2025-06-30**
# <style type="text/css">
# #T_339e3_row0_col0, #T_339e3_row0_col2, #T_339e3_row0_col3, #T_339e3_row0_col4, #T_339e3_row0_col5, #T_339e3_row1_col1, #T_339e3_row1_col6 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_339e3_row0_col1, #T_339e3_row0_col6, #T_339e3_row1_col0, #T_339e3_row1_col2, #T_339e3_row1_col3, #T_339e3_row1_col4, #T_339e3_row1_col5 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# </style>
# <table id="T_339e3">
#   <caption>Pesos</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_339e3_level0_col0" class="col_heading level0 col0" >WEGE3.SA</th>
#       <th id="T_339e3_level0_col1" class="col_heading level0 col1" >ELET3.SA</th>
#       <th id="T_339e3_level0_col2" class="col_heading level0 col2" >ITUB4.SA</th>
#       <th id="T_339e3_level0_col3" class="col_heading level0 col3" >VIVT3.SA</th>
#       <th id="T_339e3_level0_col4" class="col_heading level0 col4" >ABEV3.SA</th>
#       <th id="T_339e3_level0_col5" class="col_heading level0 col5" >CSUD3.SA</th>
#       <th id="T_339e3_level0_col6" class="col_heading level0 col6" >FIQE3.SA</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_339e3_level0_row0" class="row_heading level0 row0" >Pesos</th>
#       <td id="T_339e3_row0_col0" class="data row0 col0" >20.000000</td>
#       <td id="T_339e3_row0_col1" class="data row0 col1" >18.000000</td>
#       <td id="T_339e3_row0_col2" class="data row0 col2" >15.000000</td>
#       <td id="T_339e3_row0_col3" class="data row0 col3" >18.000000</td>
#       <td id="T_339e3_row0_col4" class="data row0 col4" >12.000000</td>
#       <td id="T_339e3_row0_col5" class="data row0 col5" >7.000000</td>
#       <td id="T_339e3_row0_col6" class="data row0 col6" >10.000000</td>
#     </tr>
#     <tr>
#       <th id="T_339e3_level0_row1" class="row_heading level0 row1" >retornos em %</th>
#       <td id="T_339e3_row1_col0" class="data row1 col0" >16.298220</td>
#       <td id="T_339e3_row1_col1" class="data row1 col1" >66.895896</td>
#       <td id="T_339e3_row1_col2" class="data row1 col2" >13.652123</td>
#       <td id="T_339e3_row1_col3" class="data row1 col3" >7.788684</td>
#       <td id="T_339e3_row1_col4" class="data row1 col4" >5.140983</td>
#       <td id="T_339e3_row1_col5" class="data row1 col5" >5.459208</td>
#       <td id="T_339e3_row1_col6" class="data row1 col6" >50.477237</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_8ae47_row0_col0, #T_8ae47_row0_col1, #T_8ae47_row0_col5, #T_8ae47_row1_col2, #T_8ae47_row1_col3, #T_8ae47_row1_col4, #T_8ae47_row1_col6 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_8ae47_row0_col2, #T_8ae47_row0_col3, #T_8ae47_row0_col4, #T_8ae47_row0_col6, #T_8ae47_row1_col0, #T_8ae47_row1_col1, #T_8ae47_row1_col5 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# </style>
# <table id="T_8ae47">
#   <caption>Pesos</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8ae47_level0_col0" class="col_heading level0 col0" >ABEV3.SA</th>
#       <th id="T_8ae47_level0_col1" class="col_heading level0 col1" >CSUD3.SA</th>
#       <th id="T_8ae47_level0_col2" class="col_heading level0 col2" >ELET3.SA</th>
#       <th id="T_8ae47_level0_col3" class="col_heading level0 col3" >FIQE3.SA</th>
#       <th id="T_8ae47_level0_col4" class="col_heading level0 col4" >ITUB4.SA</th>
#       <th id="T_8ae47_level0_col5" class="col_heading level0 col5" >VIVT3.SA</th>
#       <th id="T_8ae47_level0_col6" class="col_heading level0 col6" >WEGE3.SA</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8ae47_level0_row0" class="row_heading level0 row0" >Pesos</th>
#       <td id="T_8ae47_row0_col0" class="data row0 col0" >20.177118</td>
#       <td id="T_8ae47_row0_col1" class="data row0 col1" >10.625782</td>
#       <td id="T_8ae47_row0_col2" class="data row0 col2" >16.375782</td>
#       <td id="T_8ae47_row0_col3" class="data row0 col3" >10.881618</td>
#       <td id="T_8ae47_row0_col4" class="data row0 col4" >10.824120</td>
#       <td id="T_8ae47_row0_col5" class="data row0 col5" >12.978626</td>
#       <td id="T_8ae47_row0_col6" class="data row0 col6" >18.136954</td>
#     </tr>
#     <tr>
#       <th id="T_8ae47_level0_row1" class="row_heading level0 row1" >retornos markwitz em %</th>
#       <td id="T_8ae47_row1_col0" class="data row1 col0" >7.124777</td>
#       <td id="T_8ae47_row1_col1" class="data row1 col1" >4.306953</td>
#       <td id="T_8ae47_row1_col2" class="data row1 col2" >69.684575</td>
#       <td id="T_8ae47_row1_col3" class="data row1 col3" >53.848132</td>
#       <td id="T_8ae47_row1_col4" class="data row1 col4" >14.661462</td>
#       <td id="T_8ae47_row1_col5" class="data row1 col5" >8.339294</td>
#       <td id="T_8ae47_row1_col6" class="data row1 col6" >18.621781</td>
#     </tr>
#   </tbody>
# </table>
# ****************************************
# **O retorno da carteira para o período: 2025-12-12**
# INFO:__main__:Erro ao obter:'2025-12-12'
# Nenhum dado foi obtido!
# <style type="text/css">
# #T_1fb84_row0_col0, #T_1fb84_row0_col1, #T_1fb84_row0_col2, #T_1fb84_row0_col3, #T_1fb84_row0_col4, #T_1fb84_row0_col5, #T_1fb84_row0_col6, #T_1fb84_row0_col7, #T_1fb84_row0_col8 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# </style>
# <table id="T_1fb84">
#   <caption>Pesos</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1fb84_level0_col0" class="col_heading level0 col0" >LREN3.SA</th>
#       <th id="T_1fb84_level0_col1" class="col_heading level0 col1" >WEGE3.SA</th>
#       <th id="T_1fb84_level0_col2" class="col_heading level0 col2" >VIVT3.SA</th>
#       <th id="T_1fb84_level0_col3" class="col_heading level0 col3" >CGAS3.SA</th>
#       <th id="T_1fb84_level0_col4" class="col_heading level0 col4" >ITUB4.SA</th>
#       <th id="T_1fb84_level0_col5" class="col_heading level0 col5" >ABEV3.SA</th>
#       <th id="T_1fb84_level0_col6" class="col_heading level0 col6" >GGBR4.SA</th>
#       <th id="T_1fb84_level0_col7" class="col_heading level0 col7" >FIQE3.SA</th>
#       <th id="T_1fb84_level0_col8" class="col_heading level0 col8" >VALE3.SA</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1fb84_level0_row0" class="row_heading level0 row0" >Pesos</th>
#       <td id="T_1fb84_row0_col0" class="data row0 col0" >20.116677</td>
#       <td id="T_1fb84_row0_col1" class="data row0 col1" >16.757192</td>
#       <td id="T_1fb84_row0_col2" class="data row0 col2" >13.407765</td>
#       <td id="T_1fb84_row0_col3" class="data row0 col3" >13.407765</td>
#       <td id="T_1fb84_row0_col4" class="data row0 col4" >13.407765</td>
#       <td id="T_1fb84_row0_col5" class="data row0 col5" >10.058338</td>
#       <td id="T_1fb84_row0_col6" class="data row0 col6" >7.815329</td>
#       <td id="T_1fb84_row0_col7" class="data row0 col7" >5.029169</td>
#       <td id="T_1fb84_row0_col8" class="data row0 col8" >0.000000</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_7375a_row0_col0, #T_7375a_row0_col1, #T_7375a_row0_col2, #T_7375a_row0_col3, #T_7375a_row0_col4, #T_7375a_row0_col5, #T_7375a_row0_col6 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# </style>
# <table id="T_7375a">
#   <caption>Pesos</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7375a_level0_col0" class="col_heading level0 col0" >ABEV3.SA</th>
#       <th id="T_7375a_level0_col1" class="col_heading level0 col1" >CSUD3.SA</th>
#       <th id="T_7375a_level0_col2" class="col_heading level0 col2" >ELET3.SA</th>
#       <th id="T_7375a_level0_col3" class="col_heading level0 col3" >FIQE3.SA</th>
#       <th id="T_7375a_level0_col4" class="col_heading level0 col4" >ITUB4.SA</th>
#       <th id="T_7375a_level0_col5" class="col_heading level0 col5" >VIVT3.SA</th>
#       <th id="T_7375a_level0_col6" class="col_heading level0 col6" >WEGE3.SA</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7375a_level0_row0" class="row_heading level0 row0" >Pesos</th>
#       <td id="T_7375a_row0_col0" class="data row0 col0" >20.177118</td>
#       <td id="T_7375a_row0_col1" class="data row0 col1" >10.625782</td>
#       <td id="T_7375a_row0_col2" class="data row0 col2" >16.375782</td>
#       <td id="T_7375a_row0_col3" class="data row0 col3" >10.881618</td>
#       <td id="T_7375a_row0_col4" class="data row0 col4" >10.824120</td>
#       <td id="T_7375a_row0_col5" class="data row0 col5" >12.978626</td>
#       <td id="T_7375a_row0_col6" class="data row0 col6" >18.136954</td>
#     </tr>
#   </tbody>
# </table>

# %%
start_bove = chaves[0]
end_bove = chaves[-1]

# %%
start_bove = chaves[0]
end_bove = chaves[-1]
ibov = yf.download("^BVSP", start= start_bove, end=end_bove)["Close"]

ibov_retornos = cumulative_returns(ibov) *1000
# Out:
# C:\Users\jefer\AppData\Local\Temp\ipykernel_4584\2161183779.py:3: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   ibov = yf.download("^BVSP", start= start_bove, end=end_bove)["Close"]
# [*********************100%***********************]  1 of 1 completed

# %%
import pandas as pd
from bcb import sgs

def get_selic_multiplos_periodos(data_inicio, data_fim, anos_por_janela=5):
    """
    Busca dados da SELIC em janelas de X anos para contornar limitação da API
    """
    inicio = pd.to_datetime(data_inicio)
    fim = pd.to_datetime(data_fim)
    
    # Lista para armazenar os dataframes
    dados_completos = []
    
    # Criar janelas
    current_start = inicio
    
    while current_start < fim:
        current_end = min(current_start + pd.DateOffset(years=anos_por_janela), fim)
        
        print(f"Buscando dados de {current_start.date()} até {current_end.date()}...")
        
        try:
            # Fazer requisição para a janela atual
            dados_janela = sgs.get({'selic': 11, 
                                    #'cdi' :12
                                    }, 
                                   start=current_start.strftime('%Y-%m-%d'),
                                   end=current_end.strftime('%Y-%m-%d'))
            
            dados_completos.append(dados_janela)
            print(f"  ✓ {len(dados_janela)} registros obtidos")
            
        except Exception as e:
            print(f"  ✗ Erro ao buscar dados: {e}")

        current_start = current_end + pd.Timedelta(days=1)

    if dados_completos:
        selic_completo = pd.concat(dados_completos)
        selic_completo = selic_completo[~selic_completo.index.duplicated(keep='first')]
        selic_completo = selic_completo.sort_index()
        
        print(f"\n✓ Total de registros: {len(selic_completo)}")
        print(f"✓ Período: {selic_completo.index.min().date()} até {selic_completo.index.max().date()}")
        
        return selic_completo
    else:
        print("Nenhum dado foi obtido!")
        return None

# Usar a função
selic = get_selic_multiplos_periodos(start_bove, end_bove)
# Out:
# Buscando dados de 2016-12-31 até 2021-12-31...
#   ✓ 1254 registros obtidos
# Buscando dados de 2022-01-01 até 2025-12-12...
#   ✓ 993 registros obtidos
#
# ✓ Total de registros: 2247
# ✓ Período: 2017-01-02 até 2025-12-12

# %%
selic_acumulada =  ((selic/100 + 1).cumprod())*1000
selic_acumulada
# Out:
#                   selic
# Date
# 2017-01-02  1000.507880
# 2017-01-03  1001.016018
# 2017-01-04  1001.524414
# 2017-01-05  1002.033068
# 2017-01-06  1002.541981
# ...                 ...
# 2025-12-08  2123.608498
# 2025-12-09  2124.779265
# 2025-12-10  2125.950677
# 2025-12-11  2127.122735
# 2025-12-12  2128.295439
#
# [2247 rows x 1 columns]

# %%
retorno_acumulado_monetario = pd.concat([selic_acumulada, ibov_retornos, carteira], axis=1).rename(columns={0: "Carteira", "selic": "SELIC", "^BVSP": "IBOV",})

retorno_acumulado_monetario['Markowitz'] = carteira_marcowitz

# %%
retorno_acumulado_monetario
# Out:
#                   SELIC         IBOV     Carteira    Markowitz
# 2017-01-02  1000.507880          NaN          NaN          NaN
# 2017-01-03  1001.016018  1037.339106  1022.541164  1022.768717
# 2017-01-04  1001.524414  1033.563242  1036.459252  1028.529425
# 2017-01-05  1002.033068  1041.651983  1050.173363  1028.103730
# 2017-01-06  1002.541981  1034.838645  1046.615448  1028.489789
# ...                 ...          ...          ...          ...
# 2025-12-08  2123.608498  2654.634245  3462.831024  4399.536680
# 2025-12-09  2124.779265  2651.177231  3479.260008  4414.662708
# 2025-12-10  2125.950677  2669.536324  3468.858265  4413.840435
# 2025-12-11  2127.122735  2671.449429  3467.901759  4404.805680
# 2025-12-12  2128.295439          NaN          NaN  4465.703710
#
# [2253 rows x 4 columns]

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# ===============================================================
# MÉTRICAS
# ===============================================================

def daily_returns(prices):
    return prices.pct_change()[1:]

def annualized_volatility(daily_ret, trading_days=252):
    return daily_ret.std() * np.sqrt(trading_days)

def annualized_mean_return(daily_ret, trading_days=252):
    return daily_ret.mean() * trading_days

def cagr(prices):
    days = (prices.index[-1] - prices.index[0]).days
    years = days / 365.25
    return (prices.iloc[-1] / prices.iloc[0])**(1/years) - 1 if years > 0 else np.nan

def max_drawdown(prices):
    cum_max = prices.cummax()
    drawdowns = (prices - cum_max) / cum_max
    return drawdowns.min()

def avg_drawdown(prices):
    dd = (prices / prices.cummax()) - 1
    negatives = dd < 0
    groups = (negatives.astype(int).diff() != 0).cumsum()
    avg_dds = []
    for _, grp in dd.groupby(groups):
        if (grp < 0).any():
            avg_dds.append(grp.min())
    return np.mean(avg_dds) if avg_dds else 0.0

def calmar_ratio(prices):
    ann_ret = cagr(prices)
    mdd = max_drawdown(prices)
    return ann_ret / abs(mdd) if mdd != 0 else np.nan

def sortino_ratio(daily_ret, required_return=0.0, trading_days=252):
    rr_daily = (1 + required_return)**(1/trading_days) - 1
    downside = daily_ret[daily_ret < rr_daily] - rr_daily
    if downside.size == 0:
        return np.nan
    dd = np.sqrt((downside**2).mean()) * np.sqrt(trading_days)
    ann_ret = annualized_mean_return(daily_ret, trading_days)
    return (ann_ret - required_return) / dd if dd != 0 else np.nan

def compute_metrics(price_df):
    metrics = {}
    for col in price_df.columns:
        p = price_df[col].dropna()
        dr = daily_returns(p)
        metrics[col] = {
            "ann_vol": annualized_volatility(dr),
            "ann_mean_ret": annualized_mean_return(dr),
            "cagr": cagr(p),
            "max_drawdown": max_drawdown(p),
            "avg_drawdown": avg_drawdown(p),
            "calmar": calmar_ratio(p),
            "sortino": sortino_ratio(dr)
        }
    return pd.DataFrame(metrics).T

# %%
compute_metrics(retorno_acumulado_monetario).style.set_caption("Métricas das Carteiras").background_gradient(cmap="Blues")
# Out:
# <style type="text/css">
# #T_27a14_row0_col0, #T_27a14_row0_col1, #T_27a14_row0_col2, #T_27a14_row1_col5, #T_27a14_row1_col6, #T_27a14_row2_col3, #T_27a14_row2_col4 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_27a14_row0_col3, #T_27a14_row0_col4, #T_27a14_row2_col0, #T_27a14_row3_col1, #T_27a14_row3_col2, #T_27a14_row3_col5, #T_27a14_row3_col6 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_27a14_row0_col5, #T_27a14_row0_col6 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_27a14_row1_col0 {
#   background-color: #083d7f;
#   color: #f1f1f1;
# }
# #T_27a14_row1_col1 {
#   background-color: #7db8da;
#   color: #000000;
# }
# #T_27a14_row1_col2 {
#   background-color: #c3daee;
#   color: #000000;
# }
# #T_27a14_row1_col3 {
#   background-color: #e5eff9;
#   color: #000000;
# }
# #T_27a14_row1_col4 {
#   background-color: #b4d3e9;
#   color: #000000;
# }
# #T_27a14_row2_col1 {
#   background-color: #1967ad;
#   color: #f1f1f1;
# }
# #T_27a14_row2_col2 {
#   background-color: #3e8ec4;
#   color: #f1f1f1;
# }
# #T_27a14_row2_col5 {
#   background-color: #a8cee4;
#   color: #000000;
# }
# #T_27a14_row2_col6 {
#   background-color: #add0e6;
#   color: #000000;
# }
# #T_27a14_row3_col0 {
#   background-color: #084a91;
#   color: #f1f1f1;
# }
# #T_27a14_row3_col3 {
#   background-color: #eaf3fb;
#   color: #000000;
# }
# #T_27a14_row3_col4 {
#   background-color: #94c4df;
#   color: #000000;
# }
# </style>
# <table id="T_27a14">
#   <caption>Métricas das Carteiras</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_27a14_level0_col0" class="col_heading level0 col0" >ann_vol</th>
#       <th id="T_27a14_level0_col1" class="col_heading level0 col1" >ann_mean_ret</th>
#       <th id="T_27a14_level0_col2" class="col_heading level0 col2" >cagr</th>
#       <th id="T_27a14_level0_col3" class="col_heading level0 col3" >max_drawdown</th>
#       <th id="T_27a14_level0_col4" class="col_heading level0 col4" >avg_drawdown</th>
#       <th id="T_27a14_level0_col5" class="col_heading level0 col5" >calmar</th>
#       <th id="T_27a14_level0_col6" class="col_heading level0 col6" >sortino</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_27a14_level0_row0" class="row_heading level0 row0" >SELIC</th>
#       <td id="T_27a14_row0_col0" class="data row0 col0" >0.002377</td>
#       <td id="T_27a14_row0_col1" class="data row0 col1" >0.084707</td>
#       <td id="T_27a14_row0_col2" class="data row0 col2" >0.088079</td>
#       <td id="T_27a14_row0_col3" class="data row0 col3" >0.000000</td>
#       <td id="T_27a14_row0_col4" class="data row0 col4" >0.000000</td>
#       <td id="T_27a14_row0_col5" class="data row0 col5" >nan</td>
#       <td id="T_27a14_row0_col6" class="data row0 col6" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_27a14_level0_row1" class="row_heading level0 row1" >IBOV</th>
#       <td id="T_27a14_row1_col0" class="data row1 col0" >0.229450</td>
#       <td id="T_27a14_row1_col1" class="data row1 col1" >0.133955</td>
#       <td id="T_27a14_row1_col2" class="data row1 col2" >0.111661</td>
#       <td id="T_27a14_row1_col3" class="data row1 col3" >-0.468158</td>
#       <td id="T_27a14_row1_col4" class="data row1 col4" >-0.036645</td>
#       <td id="T_27a14_row1_col5" class="data row1 col5" >0.238512</td>
#       <td id="T_27a14_row1_col6" class="data row1 col6" >0.554214</td>
#     </tr>
#     <tr>
#       <th id="T_27a14_level0_row2" class="row_heading level0 row2" >Carteira</th>
#       <td id="T_27a14_row2_col0" class="data row2 col0" >0.241614</td>
#       <td id="T_27a14_row2_col1" class="data row2 col1" >0.169826</td>
#       <td id="T_27a14_row2_col2" class="data row2 col2" >0.146441</td>
#       <td id="T_27a14_row2_col3" class="data row2 col3" >-0.514521</td>
#       <td id="T_27a14_row2_col4" class="data row2 col4" >-0.052826</td>
#       <td id="T_27a14_row2_col5" class="data row2 col5" >0.284616</td>
#       <td id="T_27a14_row2_col6" class="data row2 col6" >0.646988</td>
#     </tr>
#     <tr>
#       <th id="T_27a14_level0_row3" class="row_heading level0 row3" >Markowitz</th>
#       <td id="T_27a14_row3_col0" class="data row3 col0" >0.217333</td>
#       <td id="T_27a14_row3_col1" class="data row3 col1" >0.193101</td>
#       <td id="T_27a14_row3_col2" class="data row3 col2" >0.179257</td>
#       <td id="T_27a14_row3_col3" class="data row3 col3" >-0.482303</td>
#       <td id="T_27a14_row3_col4" class="data row3 col4" >-0.031672</td>
#       <td id="T_27a14_row3_col5" class="data row3 col5" >0.371668</td>
#       <td id="T_27a14_row3_col6" class="data row3 col6" >0.835071</td>
#     </tr>
#   </tbody>
# </table>

# %%
from matplotlib import pyplot as plt
plt.figure(figsize=(10, 6))
cores = {'IBOV': '#1f77b4', 'Carteira': '#2ca02c', 'Markowitz': '#d62728', 'SELIC': "#d66427"}

for nome in ['IBOV', 'Carteira', 'Markowitz', 'SELIC']:
    plt.plot(
            retorno_acumulado_monetario.index,
            retorno_acumulado_monetario[nome],
                label=nome,
                color=cores[nome]
            )
    ultimo_x = retorno_acumulado_monetario[nome].index[-2]
    ultimo_y = retorno_acumulado_monetario[nome].iloc[-2]
    plt.text(
                ultimo_x, ultimo_y,
                f'R$ {ultimo_y:,.2f}',
                color=cores[nome],
                fontsize=11,
                va='center',
                fontweight='bold'
            )

plt.legend()
plt.xlabel("Data")
plt.ylabel("Retorno Monetário da Carteira")
plt.title(f"Retorno Monetário da Carteira vs Ibov vs Markowiz vs Selic (Valor inicial de R$ {1000})")
plt.show()

# %%
pesos_carteiras[chaves[0]], pesos_carteiras_marcowitz[chaves[0]]
# Out:
# ({'CSUD3.SA': 16.6651388761573,
#   'CGAS3.SA': 16.6651388761573,
#   'MDIA3.SA': 16.6651388761573,
#   'FLRY3.SA': 16.6651388761573,
#   'VIVT3.SA': 12.503437528646073,
#   'ABEV3.SA': 13.337611146759556,
#   'ITUB4.SA': 7.498395819965166},
#  {'ABEV3.SA': 0.19834362157689311,
#   'CGAS3.SA': 0.1459421731698627,
#   'CSUD3.SA': 0.06384908331126404,
#   'FLRY3.SA': 0.10411642898849506,
#   'ITUB4.SA': 0.1456984081830365,
#   'MDIA3.SA': 0.049676687588103764,
#   'VIVT3.SA': 0.2923735971823449})
